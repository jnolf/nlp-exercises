# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
url = 'https://web-scraping-demo.zgulde.net/people'
response = get(url)
response
# Out:
# <Response [200]>

# %%
print(response.text[:400])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Example People Page</title>
#     <link href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css" rel="stylesheet" />
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstr

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Example People Page</title>
# <link href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css" rel="stylesheet"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.4.1/font/bootstrap-icons.css" rel="stylesheet"/>
# </head>
# <body class="mx-auto max-w-screen-lg pb-32">
# <h1 class="my-5 text-4xl text-center">People</h1>
# <div class="my-5 text-red-800 px-5 py-3 bg-red-100 font-bold">
# <p>
# <i class="bi bi-exclamation-circle text-xl"></i>
#         All data on this page is strictly for demonstration purposes and fake.
#     </p>
# </div>
# <div class="grid grid-cols-2 gap-x-12 gap-y-16" id="people">
# <div class="person border rounded px-3 py-5 grid grid-cols-2 gap-x-3 bg-purple-50 hover:shadow-lg transition duration-500">
# ...

# %%
people = soup.select('div.person')

# %% [markdown]
# person = people[0]
# person

# %%
def parse_contact(person):
    output = {}
    output['name'] = person.find('h2').text
    output['quote'], output['email'], output['phone'], output['address'] = [p.text.strip() for p in person.find_all('p')]
    return output

# %%
pd.DataFrame([parse_contact(person) for person in people])
# Out:
#                  name                                        quote  \
# 0      Curtis Johnson               "Focused tertiary parallelism"
# 1  Christopher Taylor                "Universal multimedia policy"
# 2      Jessica Garner             "Integrated background intranet"
# 3        Sonya Cortez                       "Total 24hour toolset"
# 4       Lucas Long MD        "Devolved holistic Graphic Interface"
# 5        Crystal King  "Self-enabling zero-defect standardization"
# 6         James Gomez        "Triple-buffered incremental toolset"
# 7    Mr. Brian Glover  "Function-based grid-enabled system engine"
# 8        Aaron Miller               "Total zero-defect neural-net"
# 9       Michael Perez    "Multi-lateral high-level knowledge user"
#
#                                email                  phone  \
# 0      fernandezkristin@phillips.com             5260678039
# 1                    jon91@gmail.com     361-523-9161x54483
# ...

# %% [markdown]
# ### Acquire Codeup Blog Articles

# %%
url =  'https://codeup.com/workshops/from-bootcamp-to-bootcamp-a-military-appreciation-panel/'
headers = {'user-agent': 'Innis Data Science Cohort'}
response = get(url, headers = headers)

# %%
print(response.text[:400])
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<link rel="pingback" href="https://codeup.com/xmlrpc.php" />
#
# 	<script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
#
# 	<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin /><script id="diviarea-loader">window.DiviPopupData=wi

# %%
soup = BeautifulSoup(response.text)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://codeup.com/xmlrpc.php" rel="pingback"/>
# <script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
# ...

# %%
articles = soup.select('div.entry-content')
articles
# Out:
# [<div class="entry-content">
#  <div class="et-l et-l--post">
#  <div class="et_builder_inner_content et_pb_gutters3"><div class="et_pb_section et_pb_section_0 et_section_regular">
#  <div class="et_pb_row et_pb_row_0">
#  <div class="et_pb_column et_pb_column_4_4 et_pb_column_0 et_pb_css_mix_blend_mode_passthrough et-last-child">
#  <div class="et_pb_module et_pb_text et_pb_text_0 et_pb_text_align_left et_pb_bg_layout_light">
#  <div class="et_pb_text_inner"><p data-key="16"><span data-key="17">In honor of Military Appreciation Month, join us for a discussion with Codeup Alumni who are also Military Veterans! We will chat about their experiences attending a coding bootcamp, and how their military training set them up for success here at Codeup. Grab your virtual seat now so you can be sent the exclusive Livestream link on the 11th! </span></p>
#  <p data-key="18"><span data-key="19">Thank you to our panelists for participating: </span></p>
#  <ul>
# ...

# %%
articles[0].text
# Out:
# '\n\n\n\n\n\nIn honor of Military Appreciation Month, join us for a discussion with Codeup Alumni who are also Military Veterans! We will chat about their experiences attending a coding bootcamp, and how their military training set them up for success here at Codeup. Grab your virtual seat now so you can be sent the exclusive Livestream link on the 11th! \nThank you to our panelists for participating: \n\nChristopher Aguirre\nTaryn McKenzie \nDesiree McElroy \n\n\nAnd thanks to Codeup’s Trey Iapachino who is also an Air Force Veteran! \n\n\n\n\n\n\n\n\n\n\n\n \n\n'

# %%
# What's the title of the blog?
soup.select_one('.entry-title').text
# Out:
# 'From Bootcamp to Bootcamp | A Military Appreciation Panel'

# %%
# What's the publish date?
soup.select_one('.published').text
# Out:
# 'Apr 27, 2022'

# %%
# Pull the content?
soup.select_one('.entry-content').text.strip()
# Out:
# 'In honor of Military Appreciation Month, join us for a discussion with Codeup Alumni who are also Military Veterans! We will chat about their experiences attending a coding bootcamp, and how their military training set them up for success here at Codeup. Grab your virtual seat now so you can be sent the exclusive Livestream link on the 11th! \nThank you to our panelists for participating: \n\nChristopher Aguirre\nTaryn McKenzie \nDesiree McElroy \n\n\nAnd thanks to Codeup’s Trey Iapachino who is also an Air Force Veteran!'

# %%
def get_codeup_blog (url):
    '''
    Function goes through Codeup blog links 
    '''
    # Set the headers
    headers = {'User-Agent': 'Codeup Data Science'}    
    # Get the http response object from the server
    response = get(url, headers=headers)
    # 
    soup = BeautifulSoup(response.text)   
    # Return a dictionary of all fields
    return{
    # What's the title of the blog
    'title': soup.select_one('.entry-title').text,
    # What are it's contents
    'content': soup.select_one('.entry-content').text.strip(),
    # When was it published
    'published': soup.select_one('.published').text
    }

# %%
def get_blog_articles (urls):
    # Create a list of dictionaries
    list_dic = [get_codeup_blog(url) for url in urls] 
    # Return a data frame
    return df

# %%
urls = ['https://codeup.com/workshops/from-bootcamp-to-bootcamp-a-military-appreciation-panel/',
        'https://codeup.com/featured/our-acquisition-of-the-rackspace-cloud-academy-one-year-later/',
        'https://codeup.com/workshops/virtual/learn-to-code-html-css-on-4-30/',
        'https://codeup.com/featured/5-books-every-woman-in-tech-should-read/',
        'https://codeup.com/cybersecurity/a-rise-in-cyber-attacks-means-opportunities-for-veterans-in-san-antonio/'    
       ]

# %%
get_blog_articles(urls)
# Out:
#                                                title     published  \
# 0  From Bootcamp to Bootcamp | A Military Appreci...  Apr 27, 2022
# 1  Our Acquisition of the Rackspace Cloud Academy...  Apr 14, 2022
# 2                  Learn to Code: HTML & CSS on 4/30   Apr 1, 2022
# 3            5 Books Every Woman In Tech Should Read   Mar 8, 2022
# 4  A rise in cyber attacks means opportunities fo...  Nov 17, 2021
#
#                                              content
# 0  In honor of Military Appreciation Month, join ...
# 1  Just about a year ago on April 16th, 2021 we a...
# 2  HTML & CSS are the design building blocks of a...
# 3  On this International Women’s Day 2022 we want...
# 4  In the last few months, the US has experienced...

# %% [markdown]
# ### Acquiring InShorts Articles

# %%
categories = ['Business',
               'Sports',
               'Technology',
               'Entertainment']
url = 'https://www.inshorts.com/en/read/business'
headers = {'user-agent': 'Innis Data Science Cohort'}
response = get(url, headers = headers)
soup = BeautifulSoup(response.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <style>
#    /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
# Create a dict to showcase all required info
def parse_news_card(card, category):
    '''
    Function takes in a news card and generates a dictionary
    '''
    cards = soup.select_one('div.news-card')
    output = {}
    output['category'] = category
    output['title'] = card.select_one('a.clickable').text.strip()
    output['content'] = card.select_one('div.news-card-content').text.strip()
    output['author'] = card.select_one('.author').text
    output['published'] = card.select_one('.time').attrs['content']

    return output

# %%
headline = card.find('span', itemprop = 'headline').text
headline
# Out:
# 'Rupee hits all-time low of 77.42 against US dollar'

# %%
author = card.select_one('.author').text
author
# Out:
# 'Pragya Swastik'

# %%
content = card.select_one('div.news-card-content').text.strip()
content
# Out:
# 'The Indian rupee weakened further on Monday to close at a new all-time low of 77.50 against the US dollar, 60 paise over its previous close. During the trading session, the rupee touched its lifetime low of 77.52. The currency was weighed down by elevated crude oil prices and a widening trade deficit.\n\nshort by Pragya Swastik / \n      08:57 pm on 09 May'

# %%
timestamp = card.select_one('.time').attrs['content']
timestamp
# Out:
# '2022-05-09T15:27:43.000Z'

# %%
articles = [parse_news_card(card) for card in soup.select('.news-card')]
# Out:
# [{'title': 'Rupee closes at all-time low of 77.50 against US dollar',
#   'content': 'The Indian rupee weakened further on Monday to close at a new all-time low of 77.50 against the US dollar, 60 paise over its previous close. During the trading session, the rupee touched its lifetime low of 77.52. The currency was weighed down by elevated crude oil prices and a widening trade deficit.\n\nshort by Pragya Swastik / \n      08:57 pm on 09 May',
#   'author': 'Pragya Swastik',
#   'published': '2022-05-09T15:27:43.000Z'},
#  {'title': "India's biggest IPO of LIC subscribed nearly 3 times on final day of bidding",
# ...

# %%
def parse_business_page():    
    url = 'https://www.inshorts.com/en/read/business'
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    articles = [parse_news_card(card) for card in soup.select('.news-card')]
    return articles

# %%
parse_business_page()
# Out:
# [{'category': 'business',
#   'title': 'Rupee closes at all-time low of 77.50 against US dollar',
#   'content': 'The Indian rupee weakened further on Monday to close at a new all-time low of 77.50 against the US dollar, 60 paise over its previous close. During the trading session, the rupee touched its lifetime low of 77.52. The currency was weighed down by elevated crude oil prices and a widening trade deficit.\n\nshort by Pragya Swastik / \n      08:57 pm on 09 May',
#   'author': 'Pragya Swastik',
#   'published': '2022-05-09T15:27:43.000Z'},
#  {'category': 'business',
#   'title': 'Twitter will comply with EU content rules after takeover: Elon Musk',
# ...

# %%
def parse_inshorts_page(category):    
    url = 'https://www.inshorts.com/en/read/'+ category
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    articles = [parse_news_card(card, category) for card in soup.select('.news-card')]
    return articles

# %%
categories = ['business', 'sports', 'entertainment', 'technology']
articles = []

for category in categories:
    print(f'Getting articles for {category}')
    category_articles = parse_inshorts_page(category)
    articles.extend(category_articles)
# Out:
# Getting articles for business
# Getting articles for sports
# Getting articles for entertainment
# Getting articles for technology

# %%
pd.DataFrame(articles)
# Out:
#          category                                              title  \
# 0        business  Rupee closes at all-time low of 77.50 against ...
# 1        business  Bitcoin briefly drops below $30,000 for first ...
# 2        business  Musk's $44 bn Twitter deal at risk of being re...
# 3        business  After Musk's Taj Mahal tweet, his mother says ...
# 4        business  Office as we know it, is over: Airbnb CEO on l...
# 5        business  Layout of 'world's first Bitcoin City' in El S...
# 6        business  When are you coming to deliver 1st Tesla? Payt...
# 7        business  Microsoft to help cover US employees' travel c...
# 8        business  Twitter will comply with EU content rules afte...
# 9        business  Zomato's market cap falls below its last priva...
# 10       business  Govt calls meeting with Uber, Ola amid rising ...
# 11       business  SBI hikes interest rates on bulk term deposits...
# 12       business  JSW Group will make a $7 billion bid for Ambuj...
# ...

# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_blog_article_urls():
    '''
    Gathers URLs for blog articles
    '''
    headers = {'user-agent': 'Innis Codeup Data Science'}
    response = requests.get('https://codeup.com/blog/', headers=headers)
    soup = BeautifulSoup(response.text)
    urls = [a.attrs['href'] for a in soup.select('a.more-link')]
    return urls

def parse_blog_article(soup):
    '''
    
    '''
    return {
        'title': soup.select_one('h1.entry-title').text,
        'published': soup.select_one('.published').text,
        'content': soup.select_one('.entry-content').text.strip(),
    }

def get_blog_articles(use_cache=True):
    '''
    
    '''
    if os.path.exists('codeup_blog_articles.json') and use_cache:
        return pd.read_json('codeup_blog_articles.json')

    urls = get_blog_article_urls()
    articles = []

    for url in urls:
        print(f'fetching {url}')
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text)
        articles.append(parse_blog_article(soup))

    df = pd.DataFrame(articles)
    df.to_json('codeup_blog_articles.json', orient='records')
    return df

def parse_news_card(card, category):
    '''
    Take in a news card and generate a dictionary
    '''
    output = {}
    output['category'] = category
    output['title'] = card.select_one('a.clickable').text.strip()
    
    cards = soup.select_one('div.news-card')
    output['content'] = card.select_one('div.news-card-content').text.strip()
    output['author'] = card.select_one('.author').text
    output['published'] = card.select_one('.time').attrs['content']
    return output

def parse_inshorts_page(category): 
    '''
    
    '''
    url = 'https://www.inshorts.com/en/read/'+ category
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    articles = [parse_news_card(card, category) for card in soup.select('.news-card')]
    return articles

def get_inshorts_articles():
    '''
    Combine all articles from multiple categories into one data frame
    '''
    categories = ['business', 'sports', 'entertainment', 'technology']
    articles = []
    
    for category in categories:
        print(f'Getting articles for {category}')
        category_articles = parse_inshorts_page(category)
        articles.extend(category_articles)    
    return df

# %%
get_inshorts_articles()
# Out:
# Getting articles for business
# Getting articles for sports
# Getting articles for entertainment
# Getting articles for technology
#                                                title     published  \
# 0  From Bootcamp to Bootcamp | A Military Appreci...  Apr 27, 2022
# 1  Our Acquisition of the Rackspace Cloud Academy...  Apr 14, 2022
# 2                  Learn to Code: HTML & CSS on 4/30   Apr 1, 2022
# 3            5 Books Every Woman In Tech Should Read   Mar 8, 2022
# 4  A rise in cyber attacks means opportunities fo...  Nov 17, 2021
#
#                                              content
# 0  In honor of Military Appreciation Month, join ...
# 1  Just about a year ago on April 16th, 2021 we a...
# 2  HTML & CSS are the design building blocks of a...
# 3  On this International Women’s Day 2022 we want...
# 4  In the last few months, the US has experienced...
